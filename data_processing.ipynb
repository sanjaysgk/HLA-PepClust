# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()

chart = alt.Chart(source, title="Daily Max Temperatures (C) in Seattle, WA").mark_rect().encode(
    alt.X("date(date):O").title("Day").axis(format="%e", labelAngle=0),
    alt.Y("month(date):O").title("Month"),
    alt.Color("max(temp_max)").title(None),
    tooltip=[
        alt.Tooltip("monthdate(date)", title="Date"),
        alt.Tooltip("max(temp_max)", title="Max Temp"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)

chart.save('chart.json')

# %%
import pandas as pd
import altair as alt

# Create the dataframes for amino acids
data1 = {
    'A': [0.456, 1.781, -2.748, -1.498, -3.713, -2.001, 0.947, -0.995, -3.508],
    'R': [0.282, -3.074, -3.759, 1.628, -5.469, -1.344, 0.041, 3.832, -3.973],
    'N': [-2.387, 3.071, -3.967, 0.039, -4.905, -1.173, 2.421, 2.020, -6.237],
    'D': [-4.588, -3.802, -4.127, 2.194, -6.229, -2.416, -2.399, -2.085, -6.536],
    'C': [-3.498, -0.657, -3.108, -4.535, -4.586, -3.919, -0.907, -4.462, -1.881],
    'Q': [0.024, 0.525, -0.815, 1.408, -5.938, 0.409, 2.417, 1.460, -4.971],
    'E': [-3.030, -4.673, -4.017, 2.933, -6.064, -0.833, 1.260, -2.052, -6.338],
    'G': [-3.177, 1.259, -5.260, -1.783, -5.412, -1.667, -1.281, -0.032, -6.308],
    'H': [-2.738, -1.238, 0.111, -0.485, 2.748, 0.603, 1.228, 2.620, -5.150],
    'I': [1.080, 2.031, 0.557, -0.802, -2.059, 1.460, -0.445, -2.987, 1.921],
    'L': [-3.209, -2.464, 0.138, -1.633, 0.238, 1.370, -2.928, -1.243, 3.944],
    'K': [1.301, -4.210, -5.018, -0.568, -3.664, 0.455, -1.043, 0.887, -5.585],
    'M': [-1.921, -0.473, -1.272, -4.164, -0.761, -0.154, -2.014, -0.475, 4.555],
    'F': [-2.734, -2.756, 3.485, -3.364, 7.044, -0.221, -4.030, -2.918, 3.407],
    'P': [-5.479, -5.637, 2.069, -0.462, -3.294, -0.518, -2.464, -1.813, -5.065],
    'S': [2.834, 1.025, -3.793, 0.128, -5.948, -0.062, 0.602, -0.213, -5.957],
    'T': [0.746, 0.915, -3.685, 0.062, -5.405, 1.028, 1.774, 0.988, -3.556],
    'W': [-5.583, -5.613, 1.625, -0.785, 2.058, -0.137, -5.582, -5.409, -4.493],
    'Y': [-3.696, -4.096, 6.002, -2.587, 4.589, 0.488, -2.946, -1.924, -2.853],
    'V': [3.293, 1.179, 1.301, -1.199, -3.009, 1.050, -0.359, -3.306, 2.133]
}

data2 = {
    'A': [-2.294, -2.127, 0.229, -1.052, -1.793, -0.898, -1.383, -1.606, -2.789],
    'R': [-3.151, -1.715, -2.831, 2.448, -3.350, -1.034, -1.413, 3.354, -3.794],
    'N': [1.824, -0.678, -0.735, -1.991, 0.382, -3.255, 1.175, -1.610, -4.519],
    'D': [6.135, 4.675, 2.295, -1.374, 1.273, -3.636, 2.446, -1.931, -1.679],
    'C': [-3.405, -3.516, -2.261, -0.922, -2.306, -1.940, -2.975, -1.069, -1.942],
    'Q': [-2.094, -1.301, -0.404, -0.368, -1.505, 0.536, -0.745, 0.930, -2.614],
    'E': [-0.306, 4.472, -1.271, -0.204, -1.099, -2.766, 3.791, -0.650, -4.494],
    'G': [-2.025, -3.178, -1.777, -0.528, -1.992, -0.111, -2.906, -2.963, -3.946],
    'H': [-1.223, -0.900, -2.355, -0.501, 1.236, -0.122, 1.537, -2.166, -3.607],
    'I': [-1.002, -3.317, 0.475, -0.488, 2.493, 1.234, -2.421, -0.623, 1.016],
    'L': [-1.743, -1.281, -0.825, 1.820, 0.238, 2.188, -1.183, 1.779, 5.024],
    'K': [-2.573, -1.672, -2.796, 1.077, -3.160, -0.854, -0.787, 1.506, -3.968],
    'M': [-3.163, -2.993, 1.419, -1.405, -0.662, 0.298, -2.455, -0.762, 1.240],
    'F': [-0.898, -1.828, 3.185, -1.499, 3.854, 0.192, 1.220, 0.455, 0.931],
    'P': [-3.195, -3.755, -1.201, 0.654, -4.614, 0.342, -3.675, -0.936, -5.184],
    'S': [-1.837, -1.921, -0.477, -1.035, -2.567, -1.856, -0.128, -2.136, -4.552],
    'T': [-2.879, -1.671, 0.803, -0.419, -2.303, -1.004, -1.048, -0.522, -3.205],
    'W': [-4.383, -4.178, -0.853, -3.575, -0.517, -0.960, -3.051, -1.973, -1.044],
    'Y': [-1.915, -3.508, 0.418, -1.369, 1.096, -0.814, 0.529, -1.191, -1.141],
    'V': [-1.406, -2.509, 0.521, -0.526, 1.555, 2.240, -2.846, -0.489, -0.144]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# Melt the dataframes to long format for Altair
df1_melted = df1.reset_index().melt('index', var_name='Amino Acid', value_name='Value1')
df2_melted = df2.reset_index().melt('index', var_name='Amino Acid', value_name='Value2')

# Merge the two dataframes
df_merged = pd.merge(df1_melted, df2_melted, on=['index', 'Amino Acid'])

# Create the chart
chart = alt.Chart(df_merged).mark_circle().encode(
    x='Value1',
    y='Value2',
    color='Amino Acid',
    tooltip=['Amino Acid', 'Value1', 'Value2']
).properties(
    title='Comparison of Amino Acids'
)

chart.save('amino_acids_comparison.json')
chart

# %%
import pandas as pd
import altair as alt

# Create the dataframes for amino acids
data1 = {
    'A': [0.456, 1.781, -2.748, -1.498, -3.713, -2.001, 0.947, -0.995, -3.508],
    'R': [0.282, -3.074, -3.759, 1.628, -5.469, -1.344, 0.041, 3.832, -3.973],
    'N': [-2.387, 3.071, -3.967, 0.039, -4.905, -1.173, 2.421, 2.020, -6.237],
    'D': [-4.588, -3.802, -4.127, 2.194, -6.229, -2.416, -2.399, -2.085, -6.536],
    'C': [-3.498, -0.657, -3.108, -4.535, -4.586, -3.919, -0.907, -4.462, -1.881],
    'Q': [0.024, 0.525, -0.815, 1.408, -5.938, 0.409, 2.417, 1.460, -4.971],
    'E': [-3.030, -4.673, -4.017, 2.933, -6.064, -0.833, 1.260, -2.052, -6.338],
    'G': [-3.177, 1.259, -5.260, -1.783, -5.412, -1.667, -1.281, -0.032, -6.308],
    'H': [-2.738, -1.238, 0.111, -0.485, 2.748, 0.603, 1.228, 2.620, -5.150],
    'I': [1.080, 2.031, 0.557, -0.802, -2.059, 1.460, -0.445, -2.987, 1.921],
    'L': [-3.209, -2.464, 0.138, -1.633, 0.238, 1.370, -2.928, -1.243, 3.944],
    'K': [1.301, -4.210, -5.018, -0.568, -3.664, 0.455, -1.043, 0.887, -5.585],
    'M': [-1.921, -0.473, -1.272, -4.164, -0.761, -0.154, -2.014, -0.475, 4.555],
    'F': [-2.734, -2.756, 3.485, -3.364, 7.044, -0.221, -4.030, -2.918, 3.407],
    'P': [-5.479, -5.637, 2.069, -0.462, -3.294, -0.518, -2.464, -1.813, -5.065],
    'S': [2.834, 1.025, -3.793, 0.128, -5.948, -0.062, 0.602, -0.213, -5.957],
    'T': [0.746, 0.915, -3.685, 0.062, -5.405, 1.028, 1.774, 0.988, -3.556],
    'W': [-5.583, -5.613, 1.625, -0.785, 2.058, -0.137, -5.582, -5.409, -4.493],
    'Y': [-3.696, -4.096, 6.002, -2.587, 4.589, 0.488, -2.946, -1.924, -2.853],
    'V': [3.293, 1.179, 1.301, -1.199, -3.009, 1.050, -0.359, -3.306, 2.133]
}

data2 = {
    'A': [-2.294, -2.127, 0.229, -1.052, -1.793, -0.898, -1.383, -1.606, -2.789],
    'R': [-3.151, -1.715, -2.831, 2.448, -3.350, -1.034, -1.413, 3.354, -3.794],
    'N': [1.824, -0.678, -0.735, -1.991, 0.382, -3.255, 1.175, -1.610, -4.519],
    'D': [6.135, 4.675, 2.295, -1.374, 1.273, -3.636, 2.446, -1.931, -1.679],
    'C': [-3.405, -3.516, -2.261, -0.922, -2.306, -1.940, -2.975, -1.069, -1.942],
    'Q': [-2.094, -1.301, -0.404, -0.368, -1.505, 0.536, -0.745, 0.930, -2.614],
    'E': [-0.306, 4.472, -1.271, -0.204, -1.099, -2.766, 3.791, -0.650, -4.494],
    'G': [-2.025, -3.178, -1.777, -0.528, -1.992, -0.111, -2.906, -2.963, -3.946],
    'H': [-1.223, -0.900, -2.355, -0.501, 1.236, -0.122, 1.537, -2.166, -3.607],
    'I': [-1.002, -3.317, 0.475, -0.488, 2.493, 1.234, -2.421, -0.623, 1.016],
    'L': [-1.743, -1.281, -0.825, 1.820, 0.238, 2.188, -1.183, 1.779, 5.024],
    'K': [-2.573, -1.672, -2.796, 1.077, -3.160, -0.854, -0.787, 1.506, -3.968],
    'M': [-3.163, -2.993, 1.419, -1.405, -0.662, 0.298, -2.455, -0.762, 1.240],
    'F': [-0.898, -1.828, 3.185, -1.499, 3.854, 0.192, 1.220, 0.455, 0.931],
    'P': [-3.195, -3.755, -1.201, 0.654, -4.614, 0.342, -3.675, -0.936, -5.184],
    'S': [-1.837, -1.921, -0.477, -1.035, -2.567, -1.856, -0.128, -2.136, -4.552],
    'T': [-2.879, -1.671, 0.803, -0.419, -2.303, -1.004, -1.048, -0.522, -3.205],
    'W': [-4.383, -4.178, -0.853, -3.575, -0.517, -0.960, -3.051, -1.973, -1.044],
    'Y': [-1.915, -3.508, 0.418, -1.369, 1.096, -0.814, 0.529, -1.191, -1.141],
    'V': [-1.406, -2.509, 0.521, -0.526, 1.555, 2.240, -2.846, -0.489, -0.144]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

df1['Position'] = df1.index +1
df2['Position'] = df2.index +1
# Melt the dataframes to long format for Altair
# df1_melted = df1.reset_index().melt('Position', var_name='Amino Acid', value_name='PWM1')
# df2_melted = df2.reset_index().melt('Position', var_name='Amino Acid', value_name='PWM2')

df1_melted = df1.melt(id_vars='Position', var_name='Amino Acid', value_name='PWM1')
df2_melted = df2.melt(id_vars='Position', var_name='Amino Acid', value_name='PWM2')

# Merge the two dataframes
df_merged = pd.merge(df1_melted, df2_melted, on=['Position', 'Amino Acid'])

# Create the base chart
base = alt.Chart(df_merged,width="container").mark_circle().encode(
    x='PWM1',
    y='PWM2',
    color='Amino Acid',
    tooltip=['Amino Acid', 'PWM1', 'PWM2','Position']
)

# Calculate the correlation coefficient
corr_coef = df_merged[['PWM1', 'PWM2']].corr().iloc[0, 1]

# Create the regression line
regression_line = base.transform_regression('PWM1', 'PWM2').mark_line(opacity=0.50,shape='mark').transform_fold(
     ["reg-line"], 
     as_=["Regression", "y"]
).encode(alt.Color("Regression:N"))



# .transform_fold(
#      ["reg-line"], 
#      as_=["Regression", "y"]
# ).encode(alt.Color("Regression:N"))

# Add the correlation coefficient as text
corr_text = alt.Chart(pd.DataFrame({
    'PWM1': [df_merged['PWM1'].min()],
    'PWM2': [df_merged['PWM2'].max()],
    'text': [f'Correlation: {corr_coef:.2f}']
})).mark_text(align='left', baseline='top', dx=8, dy=-5).encode(
    x='PWM1:Q',
    y='PWM2:Q',
    text='text:N'
)

# Combine the charts
chart = base + regression_line + corr_text

chart.save('data/outputM/clust_result/amino_acids_comparison_with_correlation.json')
chart
# Out:
# alt.LayerChart(...)

# %%
df_merged
# Out:
#      Position Amino Acid   PWM1   PWM2
# 0           1          A  0.456 -2.294
# 1           2          A  1.781 -2.127
# 2           3          A -2.748  0.229
# 3           4          A -1.498 -1.052
# 4           5          A -3.713 -1.793
# ..        ...        ...    ...    ...
# 175         5          V -3.009  1.555
# 176         6          V  1.050  2.240
# 177         7          V -0.359 -2.846
# 178         8          V -3.306 -0.489
# 179         9          V  2.133 -0.144
#
# [180 rows x 4 columns]

# %%
df_merged['Amino Acid'].unique()
# Out:
# array(['A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M',
#        'F', 'P', 'S', 'T', 'W', 'Y', 'V'], dtype=object)

# %%
# !pip install vega_datasets
import pandas as pd
import altair as alt
import pandas as pd
from scipy.stats import pearsonr
# Create the dataframes for amino acids
data1 = {
    'A': [0.456, 1.781, -2.748, -1.498, -3.713, -2.001, 0.947, -0.995, -3.508],
    'R': [0.282, -3.074, -3.759, 1.628, -5.469, -1.344, 0.041, 3.832, -3.973],
    'N': [-2.387, 3.071, -3.967, 0.039, -4.905, -1.173, 2.421, 2.020, -6.237],
    'D': [-4.588, -3.802, -4.127, 2.194, -6.229, -2.416, -2.399, -2.085, -6.536],
    'C': [-3.498, -0.657, -3.108, -4.535, -4.586, -3.919, -0.907, -4.462, -1.881],
    'Q': [0.024, 0.525, -0.815, 1.408, -5.938, 0.409, 2.417, 1.460, -4.971],
    'E': [-3.030, -4.673, -4.017, 2.933, -6.064, -0.833, 1.260, -2.052, -6.338],
    'G': [-3.177, 1.259, -5.260, -1.783, -5.412, -1.667, -1.281, -0.032, -6.308],
    'H': [-2.738, -1.238, 0.111, -0.485, 2.748, 0.603, 1.228, 2.620, -5.150],
    'I': [1.080, 2.031, 0.557, -0.802, -2.059, 1.460, -0.445, -2.987, 1.921],
    'L': [-3.209, -2.464, 0.138, -1.633, 0.238, 1.370, -2.928, -1.243, 3.944],
    'K': [1.301, -4.210, -5.018, -0.568, -3.664, 0.455, -1.043, 0.887, -5.585],
    'M': [-1.921, -0.473, -1.272, -4.164, -0.761, -0.154, -2.014, -0.475, 4.555],
    'F': [-2.734, -2.756, 3.485, -3.364, 7.044, -0.221, -4.030, -2.918, 3.407],
    'P': [-5.479, -5.637, 2.069, -0.462, -3.294, -0.518, -2.464, -1.813, -5.065],
    'S': [2.834, 1.025, -3.793, 0.128, -5.948, -0.062, 0.602, -0.213, -5.957],
    'T': [0.746, 0.915, -3.685, 0.062, -5.405, 1.028, 1.774, 0.988, -3.556],
    'W': [-5.583, -5.613, 1.625, -0.785, 2.058, -0.137, -5.582, -5.409, -4.493],
    'Y': [-3.696, -4.096, 6.002, -2.587, 4.589, 0.488, -2.946, -1.924, -2.853],
    'V': [3.293, 1.179, 1.301, -1.199, -3.009, 1.050, -0.359, -3.306, 2.133]
}

data2 = {
    'A': [-2.294, -2.127, 0.229, -1.052, -1.793, -0.898, -1.383, -1.606, -2.789],
    'R': [-3.151, -1.715, -2.831, 2.448, -3.350, -1.034, -1.413, 3.354, -3.794],
    'N': [1.824, -0.678, -0.735, -1.991, 0.382, -3.255, 1.175, -1.610, -4.519],
    'D': [6.135, 4.675, 2.295, -1.374, 1.273, -3.636, 2.446, -1.931, -1.679],
    'C': [-3.405, -3.516, -2.261, -0.922, -2.306, -1.940, -2.975, -1.069, -1.942],
    'Q': [-2.094, -1.301, -0.404, -0.368, -1.505, 0.536, -0.745, 0.930, -2.614],
    'E': [-0.306, 4.472, -1.271, -0.204, -1.099, -2.766, 3.791, -0.650, -4.494],
    'G': [-2.025, -3.178, -1.777, -0.528, -1.992, -0.111, -2.906, -2.963, -3.946],
    'H': [-1.223, -0.900, -2.355, -0.501, 1.236, -0.122, 1.537, -2.166, -3.607],
    'I': [-1.002, -3.317, 0.475, -0.488, 2.493, 1.234, -2.421, -0.623, 1.016],
    'L': [-1.743, -1.281, -0.825, 1.820, 0.238, 2.188, -1.183, 1.779, 5.024],
    'K': [-2.573, -1.672, -2.796, 1.077, -3.160, -0.854, -0.787, 1.506, -3.968],
    'M': [-3.163, -2.993, 1.419, -1.405, -0.662, 0.298, -2.455, -0.762, 1.240],
    'F': [-0.898, -1.828, 3.185, -1.499, 3.854, 0.192, 1.220, 0.455, 0.931],
    'P': [-3.195, -3.755, -1.201, 0.654, -4.614, 0.342, -3.675, -0.936, -5.184],
    'S': [-1.837, -1.921, -0.477, -1.035, -2.567, -1.856, -0.128, -2.136, -4.552],
    'T': [-2.879, -1.671, 0.803, -0.419, -2.303, -1.004, -1.048, -0.522, -3.205],
    'W': [-4.383, -4.178, -0.853, -3.575, -0.517, -0.960, -3.051, -1.973, -1.044],
    'Y': [-1.915, -3.508, 0.418, -1.369, 1.096, -0.814, 0.529, -1.191, -1.141],
    'V': [-1.406, -2.509, 0.521, -0.526, 1.555, 2.240, -2.846, -0.489, -0.144]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)
print(df1.shape)
df1['posistion'] = df1.index +1
df2['posistion'] = df2.index +1
df1 = df1.melt(id_vars='posistion', var_name='Amino Acid', value_name='PWM1')
df2 = df2.melt(id_vars='posistion', var_name='Amino Acid', value_name='PWM2')

print(df1.shape)
print(df2.shape)
merge_df = pd.merge(df1, df2, on=['posistion', 'Amino Acid'])


# Melt the dataframes to long format for Altair
# df1_melted = df1.reset_index().melt('index', var_name='Amino Acid', value_name='Value1')
# df2_melted = df2.reset_index().melt('index', var_name='Amino Acid', value_name='Value2')

print(merge_df)



# Assuming merge_df is already loaded
# Group by Position and Amino Acid, then compute Pearson correlation
correlations = []

grouped = merge_df.groupby(['posistion', 'Amino Acid'])

for (position, amino_acid), group in grouped:
    print(group)
    print(position, amino_acid)
    print(len(group),"##"*10)
    if len(group) > 1:  # Ensure there are enough values to compute correlation
        corr, _ = pearsonr(group['PWM1'], group['PWM2'])
        print(corr,"###"*100)
        correlations.append([position, amino_acid, corr])
    else:
        correlations.append([position, amino_acid, None])  # Not enough data

# Convert results into a DataFrame
correlation_df = pd.DataFrame(correlations, columns=['Position', 'Amino Acid', 'Correlation'])

# Display or save results
print(correlation_df)

# df1_melted
# chart = alt.Chart(source, title="Daily Max Temperatures (C) in Seattle, WA").mark_rect().encode(
#     alt.X("date(date):O").title("Day").axis(format="%e", labelAngle=0),
#     alt.Y("month(date):O").title("Month"),
#     alt.Color("max(temp_max)").title(None),
#     tooltip=[
#         alt.Tooltip("monthdate(date)", title="Date"),
#         alt.Tooltip("max(temp_max)", title="Max Temp"),
#     ],
# ).configure_view(
#     step=13,
#     strokeWidth=0
# ).configure_axis(
#     domain=False
# )

# chart.save('chart.json')
# Out:
# (9, 20)
# (180, 3)
# (180, 3)
#      posistion Amino Acid   PWM1   PWM2
# 0            1          A  0.456 -2.294
# 1            2          A  1.781 -2.127
# 2            3          A -2.748  0.229
# 3            4          A -1.498 -1.052
# 4            5          A -3.713 -1.793
# ..         ...        ...    ...    ...
# 175          5          V -3.009  1.555
# 176          6          V  1.050  2.240
# 177          7          V -0.359 -2.846
# 178          8          V -3.306 -0.489
# 179          9          V  2.133 -0.144
#
# [180 rows x 4 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 80
#      76 correlations = []
#      78 grouped = merge_df.groupby(['posistion', 'Amino Acid']).mean()
# ---> 80 for (position, amino_acid), group in grouped:
#      81     print(group)
#      82     print(position, amino_acid)
#
# ...

# %%
# !ls
# Out:
# Dockerfile               config.py                output_imggrid_dict.png
# HLA_PEPCLUST.egg-info    data                     output_imggrid_dict2.png
# README.md                data_processing.ipynb    pyproject.toml
# __init__.py              docker-compose.yml       requirements.txt
# app                      hlapepclust-env          setup.py
# assets                   model                    test
# build                    output                   test_results
# cli                      output_imggrid.png

# %%
merge_df.groupby(['posistion', 'Amino Acid']).mean().apply(lambda x: pearsonr(x['PWM1'], x['PWM2'])[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/bioinformatics/lib/python3.9/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'PWM1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 merge_df.groupby(['posistion', 'Amino Acid']).mean().apply(lambda x: pearsonr(x['PWM1'], x['PWM2'])[0])
#
# ...

# %%
import pandas as pd
from scipy.stats import pearsonr

# Rename 'posistion' to 'Position' for consistency
merge_df.rename(columns={'posistion': 'Position'}, inplace=True)

# Group by Position and Amino Acid
correlations = []
for (position, amino_acid), group in merge_df.groupby(['Position', 'Amino Acid']):
    if len(group) > 1:  # Pearson requires at least two values
        corr, _ = pearsonr(group['PWM1'], group['PWM2'])
    else:
        corr = None  # Not enough data to compute correlation
    correlations.append({'Position': position, 'Amino Acid': amino_acid, 'Correlation': corr})

# Convert to DataFrame
correlation_df = pd.DataFrame(correlations)

# Display result
print(correlation_df)
# Out:
#      Position Amino Acid Correlation
# 0           1          A        None
# 1           1          C        None
# 2           1          D        None
# 3           1          E        None
# 4           1          F        None
# ..        ...        ...         ...
# 175         9          S        None
# 176         9          T        None
# 177         9          V        None
# 178         9          W        None
# 179         9          Y        None
#
# [180 rows x 3 columns]

# %%
import pandas as pd
from scipy.stats import pearsonr

# Ensure correct column names
merge_df.rename(columns={'posistion': 'Position'}, inplace=True)

# Compute correlation for each Amino Acid across all Positions
correlations = []
for amino_acid, group in merge_df.groupby('Amino Acid'):
    if len(group) > 1:  # Pearson requires at least two values
        corr, _ = pearsonr(group['PWM1'], group['PWM2'])
    else:
        corr = None  # Not enough data to compute correlation
    correlations.append({'Amino Acid': amino_acid, 'Correlation': corr})

# Convert to DataFrame
correlation_df = pd.DataFrame(correlations)

# Display result
print(correlation_df)
# Out:
#    Amino Acid  Correlation
# 0           A    -0.181539
# 1           C    -0.658213
# 2           D    -0.305922
# 3           E     0.298558
# 4           F     0.796131
# 5           G     0.051094
# 6           H     0.602886
# 7           I    -0.206794
# 8           K     0.667037
# 9           L     0.819252
# 10          M     0.519213
# 11          N     0.261721
# 12          P     0.741066
# 13          Q     0.597692
# 14          R     0.834810
# 15          S     0.502464
# 16          T     0.149238
# 17          V    -0.189528
# 18          W     0.647661
# 19          Y     0.716612

# %%
from jinja2 import Template

html_header = """
  <!doctype html>
  <html lang="en" data-bs-theme="auto">

  <meta charset="utf-8">
  <meta name="viewport" content="width=device-width, initial-scale=1">
  <meta name="description" content="">
  <meta name="author" content="Mark Otto, Jacob Thornton, and Bootstrap contributors">
  <meta name="generator" content="Hugo 0.122.0">
  <title>Clust-search v0.01-dev</title>



  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@docsearch/css@3">
  <!-- icon -->
  <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.11.3/font/bootstrap-icons.min.css">

  <!-- Chart Library -->
  <script src="https://cdn.jsdelivr.net/npm/vega@5"></script>
  <script src="https://cdn.jsdelivr.net/npm/vega-lite@5"></script>
  <script src="https://cdn.jsdelivr.net/npm/vega-embed@6"></script>
  <!-- Boostrap -->
  <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.2/dist/css/bootstrap.min.css" rel="stylesheet"
    integrity="sha384-EVSTQN3/azprG1Anm3QDgpJLIm9Nao0Yz1ztcQTwFspd3yD65VohhpuuCOmLASjC" crossorigin="anonymous">
  <style>
    .bd-placeholder-img {
      font-size: 1.125rem;
      text-anchor: middle;
      -webkit-user-select: none;
      -moz-user-select: none;
      user-select: none;
    }

    @media (min-width: 768px) {
      .bd-placeholder-img-lg {
        font-size: 3.5rem;
      }
    }

    .b-example-divider {
      width: 100%;
      height: 3rem;
      background-color: rgba(0, 0, 0, .1);
      border: solid rgba(0, 0, 0, .15);
      border-width: 1px 0;
      box-shadow: inset 0 .5em 1.5em rgba(0, 0, 0, .1), inset 0 .125em .5em rgba(0, 0, 0, .15);
    }

    .b-example-vr {
      flex-shrink: 0;
      width: 1.5rem;
      height: 100vh;
    }

    .bi {
      vertical-align: -.125em;
      fill: currentColor;
    }

    .nav-scroller {
      position: relative;
      z-index: 2;
      height: 2.75rem;
      overflow-y: hidden;
    }

    .nav-scroller .nav {
      display: flex;
      flex-wrap: nowrap;
      padding-bottom: 1rem;
      margin-top: -1px;
      overflow-x: auto;
      text-align: center;
      white-space: nowrap;
      -webkit-overflow-scrolling: touch;
    }

    .btn-bd-primary {
      --bd-violet-bg: #712cf9;
      --bd-violet-rgb: 112.520718, 44.062154, 249.437846;

      --bs-btn-font-weight: 600;
      --bs-btn-color: var(--bs-white);
      --bs-btn-bg: var(--bd-violet-bg);
      --bs-btn-border-color: var(--bd-violet-bg);
      --bs-btn-hover-color: var(--bs-white);
      --bs-btn-hover-bg: #6528e0;
      --bs-btn-hover-border-color: #6528e0;
      --bs-btn-focus-shadow-rgb: var(--bd-violet-rgb);
      --bs-btn-active-color: var(--bs-btn-hover-color);
      --bs-btn-active-bg: #5a23c8;
      --bs-btn-active-border-color: #5a23c8;
    }

    .bd-mode-toggle {
      z-index: 1500;
    }

    .bd-mode-toggle .dropdown-menu .active .bi {
      display: block !important;
    }
    .card {
      position: relative;
    }
    .card img {
      width: 100%;
      height: 350px;
    }
  </style>


  </head>
"""

body_start = '''

<body>




  <main>
    <div class="album py-5 bg-body-tertiary">
      <div class="container">
        <div class="row">
'''

def insert_script_hla_section(script_data_path,div_id):
  script_template = Template('''
  fetch('{{ script_data_path }}')
    .then(response => response.json())
    .then(data => {
      console.log(data);
      // Process the data as needed
      var opt = {"renderer": "canvas", "actions": false};
      vegaEmbed("#{{ div_id }}", data, opt);
    })
    .catch(error => console.error('Error fetching the JSON data:', error));
  ''')
  return script_template.render(script_data_path=script_data_path, div_id=div_id)



def render_hla_section(hla_name, correlation_chart_id, best_cluster_img, naturally_presented_img):
    template = Template('''
    <div class="row" style="border: 2px solid #007bff;">
      <div class="row">
        <h3 style="text-align: center;">{{ hla_name }}</h3>
      </div>
      <div class="row">
        <div class="col">
          <div class="card">
            <h5 style="text-align: center;">Co-relation</h5>
            <div id="{{correlation_chart_id}}"></div>
          </div>
        </div>
        <div class="col">
          <div class="card">
            <h5 style="text-align: center;">Identified Best Cluster</h5>
            <div class="card">
              {% if best_cluster_img %}
              <img src="{{ best_cluster_img }}" class="bd-placeholder-img card-img" width="100%" height="260" alt="No Image">
              {% else %}
              <div id="no-image"></div>
              {% endif %}
              <div style="position: absolute; top: 5px; right: 10px;">
                <i class="bi bi-three-dots-vertical" id="dropdownMenuButton" data-bs-toggle="dropdown" aria-expanded="false"></i>
                <div class="dropdown-menu">
                  <h6 class="dropdown-header">Download</h6>
                  {% if best_cluster_img %}
                  <a class="dropdown-item" href="{{ best_cluster_img }}">Download</a>
                  {% endif %}
                </div>
              </div>
            </div>
          </div>
        </div>
        <div class="col">
          <div class="card">
            <h5 style="text-align: center;">Naturally presented {{ hla_name }}</h5>
            <div class="card">
              {% if naturally_presented_img %}
              <img src="{{ naturally_presented_img }}" class="bd-placeholder-img card-img" width="100%" height="260" alt="No Image">
              {% else %}
              <div id="no-image"></div>
              {% endif %}
              <div style="position: absolute; top: 5px; right: 10px;">
                <i class="bi bi-three-dots-vertical" id="dropdownMenuButton" data-bs-toggle="dropdown" aria-expanded="false"></i>
                <div class="dropdown-menu">
                  <h6 class="dropdown-header">Download</h6>
                  {% if naturally_presented_img %}
                  <a class="dropdown-item" href="{{ naturally_presented_img }}">Download</a>
                  {% endif %}
                </div>
              </div>
            </div>
          </div>
        </div>
      </div>
    </div>
    ''')
    return template.render(hla_name=hla_name, correlation_chart_id=correlation_chart_id, best_cluster_img=best_cluster_img, naturally_presented_img=naturally_presented_img)

# Example usage:
print(render_hla_section("HLA-A", "viz2", "cluster-img/gibbs_logos_1of2-001.jpg", None))
# Example usage
dynamic_html = render_hla_section(
    hla_name="HLA-A",
    correlation_chart_id="viz2",  # Replace with actual Vega chart embedding
    best_cluster_img="cluster-img/gibbs_logos_1of2-001.jpg",
    naturally_presented_img="allotypes-img/H2_Kk.png"
)

# Save to a file
with open("data/outputM/jinja_output.html", "w") as f:
    f.write(dynamic_html)
print(dynamic_html)

print("HTML file generated successfully!")
# Out:
#     <div class="row" style="border: 2px solid #007bff;">
#       <div class="row">
#         <h3 style="text-align: center;">HLA-A</h3>
#       </div>
#       <div class="row">
#         <div class="col">
#           <div class="card">
#             <h5 style="text-align: center;">Co-relation</h5>
#             <div id="viz2"></div>
#           </div>
#         </div>
#         <div class="col">
#           <div class="card">
#             <h5 style="text-align: center;">Identified Best Cluster</h5>
#             <div class="card">
#
#               <img src="cluster-img/gibbs_logos_1of2-001.jpg" class="bd-placeholder-img card-img" width="100%" height="260" alt="No Image">
#
#               <div style="position: absolute; top: 5px; right: 10px;">
#                 <i class="bi bi-three-dots-vertical" id="dropdownMenuButton" data-bs-toggle="dropdown" aria-expanded="false"></i>
#                 <div class="dropdown-menu">
#                   <h6 class="dropdown-header">Download</h6>
# ...

# %%
source = data.seattle_weather()
source
# Out:
#            date  precipitation  temp_max  temp_min  wind  weather
# 0    2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1    2012-01-02           10.9      10.6       2.8   4.5     rain
# 2    2012-01-03            0.8      11.7       7.2   2.3     rain
# 3    2012-01-04           20.3      12.2       5.6   4.7     rain
# 4    2012-01-05            1.3       8.9       2.8   6.1     rain
# ...         ...            ...       ...       ...   ...      ...
# 1456 2015-12-27            8.6       4.4       1.7   2.9      fog
# 1457 2015-12-28            1.5       5.0       1.7   1.3      fog
# 1458 2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
import altair as alt
from vega_datasets import data

source = data.seattle_weather()

alt.Chart(source, title="Daily Max Temperatures (C) in Seattle, WA").mark_rect().encode(
    alt.X("date(date):O").title("Day").axis(format="%e", labelAngle=0),
    alt.Y("month(date):O").title("Month"),
    alt.Color("max(temp_max)").title(None),
    tooltip=[
        alt.Tooltip("monthdate(date)", title="Date"),
        alt.Tooltip("max(temp_max)", title="Max Temp"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)
# Out:
# alt.Chart(...)

# %%
df = pd.read_csv("output/finalv1/clust_result/corr-data/corr_matrix.csv")

# %%
df
# Out:
#    Cluster    HLA  Correlation
# 0     5of5  H2_Db         0.87
# 1     4of5  H2_Kb         0.87
# 2     1of5  H2_Kb         0.75
# 3     4of5  H2_Dd         0.55
# 4     4of5  H2_Db         0.50
# 5     5of5  H2_Dd         0.47
# 6     5of5  H2_Kb         0.41
# 7     5of5  H2_Kd         0.38
# 8     4of5  H2_Kd         0.35
# 9     5of5  H2_Dq         0.35
# 10    1of5  H2_Dd         0.33
# 11    5of5  H2_LD         0.32
# 12    4of5  H2_Kk         0.30
# 13    1of5  H2_Db         0.30
# 14    4of5  H2_Dq         0.27
# 15    4of5  H2_Kq         0.27
# 16    4of5  H2_LD         0.26
# 17    5of5  H2_Kq         0.25
# 18    2of5  H2_Kb         0.24
# 19    1of5  H2_Kd         0.23
# 20    5of5  H2_Kk         0.22
# 21    1of5  H2_Dq         0.21
# 22    2of5  H2_Dq         0.20
# 23    1of5  H2_Kk         0.20
# 24    1of5  H2_LD         0.16
# 25    2of5  H2_Kq         0.16
# 26    2of5  H2_Kk         0.15
# 27    2of5  H2_Db         0.14
# 28    1of5  H2_Kq         0.10
# ...

# %%
alt.Chart(df).mark_rect().encode(
    alt.X("HLA:O").title("HLA").axis(labelAngle=-45),
    alt.Y("Cluster:O").title("Cluster"),
    alt.Color("Correlation").title(None),
    tooltip=[
        alt.Tooltip("HLA", title="HLA"),
        alt.Tooltip("Cluster", title="Cluster"),
        alt.Tooltip("Correlation", title="Correlation"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)
# Out:
# alt.Chart(...)

# %%
import altair as alt

threshold = 0.5  # Set your threshold value

chart = alt.Chart(df).mark_rect().encode(
    alt.X("HLA:O").title("HLA"),
    alt.Y("Cluster:O").title("Cluster"),
    alt.Color(
        "Correlation",
        scale=alt.Scale(
            domain=[df["Correlation"].min(), threshold, df["Correlation"].max()],
            range=["#d3d3d3", "#add8e6", "#ff4500"],  # Low values fade, high values bright
        ),
        legend=None
    ),
    tooltip=[
        alt.Tooltip("HLA", title="HLA"),
        alt.Tooltip("Cluster", title="Cluster"),
        alt.Tooltip("Correlation", title="Correlation"),
    ],
).configure_view(
    step=13,
    strokeWidth=0
).configure_axis(
    domain=False
)

chart
# Out:
# alt.Chart(...)
